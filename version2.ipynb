# %% [markdown]
# ### tp 3

# %%
import matplotlib.pyplot as plt
import numpy as np

import tkinter as tk
from tkinter import ttk

fenetre=tk.Tk()
fenetre.geometry("600x800")
fenetre.title("notes semestre 1")

frm=ttk.Frame(fenetre)
frm.grid()
def valid():
    a=zone1.get()+zone2.get()
    verif=ttk.Label(frm,text=zone1.get())
    verif.grid(column=1,row=20,pady=20)
     

zone1=ttk.Entry(frm)                  
zone1.grid(column=1,row=0)

texte1=ttk.Label(frm, text="R101")
texte1.grid(column=0,row=0)

zone2=ttk.Entry(frm)  
zone2.grid(column=1,row=1) 

texte2=ttk.Label(frm, text="R102")
texte2.grid(column=0,row=1)

zone3=ttk.Entry(frm)
zone3.grid(column=1,row=2)

texte3=ttk.Label(frm, text="R103")
texte3.grid(column=0,row=2)

zone4=ttk.Entry(frm)                       
zone4.grid(column=1,row=3) 

texte4=ttk.Label(frm, text="R104")
texte4.grid(column=0,row=3)

zone5=ttk.Entry(frm)
zone5.grid(column=1,row=4) 

texte5=ttk.Label(frm, text="R105")
texte5.grid(column=0,row=4)

zone6=ttk.Entry(frm)
zone6.grid(column=1,row=5)

texte6=ttk.Label(frm, text="R106")
texte6.grid(column=0,row=5)

zone7=ttk.Entry(frm)                      
zone7.grid(column=1,row=6)

texte7=ttk.Label(frm, text="R107")
texte7.grid(column=0,row=6)

zone8=ttk.Entry(frm)
zone8.grid(column=1,row=7)

texte8=ttk.Label(frm, text="R108")
texte8.grid(column=0,row=7)

zone9=ttk.Entry(frm)
zone9.grid(column=1,row=8)

texte10=ttk.Label(frm, text="R109")
texte10.grid(column=0,row=8)

zone11=ttk.Entry(frm)
zone11.grid(column=1,row=9)

texte11=ttk.Label(frm, text="R110")
texte11.grid(column=0,row=9)

zone12=ttk.Entry(frm)
zone12.grid(column=1,row=10)

texte12=ttk.Label(frm, text="R111")
texte12.grid(column=0,row=10)

zone13=ttk.Entry(frm)
zone13.grid(column=1,row=11)

texte13=ttk.Label(frm, text="R112")
texte13.grid(column=0,row=11)

zone12=ttk.Entry(frm)
zone12.grid(column=1,row=12)

texte12=ttk.Label(frm, text="R113")
texte12.grid(column=0,row=12)

zone13=ttk.Entry(frm)
zone13.grid(column=1,row=13)

texte13=ttk.Label(frm, text="R114")
texte13.grid(column=0,row=13)

zone14=ttk.Entry(frm)
zone14.grid(column=1,row=14)

texte14=ttk.Label(frm, text="R115")
texte14.grid(column=0,row=14)

zone15=ttk.Entry(frm)
zone15.grid(column=1,row=15)

texte15=ttk.Label(frm, text="sae12")
texte15.grid(column=0,row=15)

zone16=ttk.Entry(frm)
zone16.grid(column=1,row=16)

texte16=ttk.Label(frm, text="sae13")
texte16.grid(column=0,row=16)

zone17=ttk.Entry(frm)
zone17.grid(column=1,row=17)

texte17=ttk.Label(frm, text="sae14")
texte17.grid(column=0,row=17)

zone18=ttk.Entry(frm)
zone18.grid(column=1,row=18)

texte18=ttk.Label(frm, text="sae15")
texte18.grid(column=0,row=18)

zone19=ttk.Entry(frm)
zone19.grid(column=1,row=19)

texte1=ttk.Label(frm, text="sae16")
texte1.grid(column=0,row=19)

btn2=ttk.Button(frm,text="valider",command=valid)
btn2.grid(column=0,row=20,pady=20)  

coef_ue1={
    "R101":10, "R102":10,"R103":7, "R104":7,"R106":5,
    "R108":6, "R110":5, "R111":4, "R112":2, "R113":5,
    "R114":5, "SAE11":20, "SAE12":20, "SAE16":7
}
coef_ue2={
    "R101":4, "R103":2, "R104":8, "R105":6, "R110":5,
    "R111":5, "R112":2, "R113":9, "R114":9,
    "R115":3, "SAE13":20, "SAE16":20,
}
coef_ue3={
    "R101":4, "R103":2, "R106":5, "R107":15, "R108":6,
    "R109":4, "R110":5, "R111":5,"R112":2, "R115":3,
    "SAE14":20, "SAE15":20, "SAE16":7
}
notes = {
    'R101': 6, 'R102': 4, 'R103': 11, 'R104':12,
    'R105': 12, 'R106': 4, 'R107': 11, 'R108': 8,
    'R109': 8, 'R110': 14, 'R111': 4, 'R112': 12,
    'R113': 13, 'R114': 3, 'R115': 11,
    'SAE11': 11, 'SAE13': 9, 'SAE14': 9,
    'SAE15': 12, 'SAE16': 15
}

def calculer_moyenne_ue(coefs, notes):
    total_points = 0
    total_coefs = 0
    for matiere, coef in coefs.items():
        if matiere in notes:
            total_points += notes[matiere] * coef
            total_coefs += coef
    if total_coefs == 0:
        return 0
    return total_points / total_coefs

moyenne_ue1 = calculer_moyenne_ue(coef_ue1, notes)
moyenne_ue2 = calculer_moyenne_ue(coef_ue2, notes)
moyenne_ue3 = calculer_moyenne_ue(coef_ue3, notes)

notes_ue1 = sum(coef_ue1.values())
notes_ue2 = sum(coef_ue2.values())
notes_ue3 = sum(coef_ue3.values())
notes_total = notes_ue1 + notes_ue2 + notes_ue3

def get_color(value):
    if value  >= 10:
        return 'green'
    else:   
        if value >=8: return 'orange'
    if value <8: return 'red' 
values = [moyenne_ue1, moyenne_ue2, moyenne_ue3]
colors = [get_color(val) for val in values]
plt.bar(['UE1' , 'UE2' , 'UE3'], values, color=colors)
plt.show()
fenetre.mainloop()
